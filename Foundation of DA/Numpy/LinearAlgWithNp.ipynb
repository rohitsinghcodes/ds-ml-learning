# %% [markdown]
# # Dot Product and matrix multiplication

# %% [markdown]
# #### Dot Product

# %%
import numpy as np
a = np.array([1, 2])
b = np.array([2, 3])
dot_product = np.dot(a, b)
print("Dot Product:", dot_product)
