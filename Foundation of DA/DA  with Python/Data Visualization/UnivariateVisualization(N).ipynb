# %% [markdown]
# Histogram: Visualizing Frequency Distribution

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# Load the dataset
df = pd.read_csv("AB_NYC_2019.csv")

# Plotting a histogram for the 'price' column
sns.histplot(df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Plotting a histogram for prices less than $500
sns.histplot(df[df["price"] < 500]["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Plotting a histogram for the 'number_of_reviews' column
sns.histplot(df[df["number_of_reviews"] < 100]["number_of_reviews"])
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='Count'>

# %% [markdown]
# Visualizing Probability Distribution

# %%
# Plotting a distplot for the 'price' column
sns.distplot(df["price"])
# Out:
# C:\Users\Rohit Kumar\AppData\Local\Temp\ipykernel_11268\4041815646.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
# Binned value counts for the 'price' column
df["price"].value_counts(bins=20)
# Out:
# (-10.001, 500.0]     47891
# (500.0, 1000.0]        805
# (1000.0, 1500.0]       100
# (1500.0, 2000.0]        53
# (2500.0, 3000.0]        21
# (2000.0, 2500.0]        20
# (3500.0, 4000.0]        11
# (4000.0, 4500.0]         6
# (4500.0, 5000.0]         6
# (9500.0, 10000.0]        6
# (6000.0, 6500.0]         4
# (3000.0, 3500.0]         2
# (5500.0, 6000.0]         2
# (5000.0, 5500.0]         2
# (7500.0, 8000.0]         2
# (7000.0, 7500.0]         2
# (6500.0, 7000.0]         1
# (8000.0, 8500.0]         1
# (8500.0, 9000.0]         0
# (9000.0, 9500.0]         0
# Name: count, dtype: int64

# %% [markdown]
# Identifying Outliers

# %%
# Plotting a box plot for the 'price' column
sns.boxplot(df[df["price"] < 500]["price"])
# Out:
# <Axes: ylabel='price'>

# %%
# Plotting a box plot for the 'reviews_per_month' column
sns.boxplot(df[df["reviews_per_month"] < 10]["reviews_per_month"])
# Out:
# <Axes: ylabel='reviews_per_month'>

# %% [markdown]
# Combining Distribution and Box Plot

# %%
# Plotting a violin plot for the 'age' column
df2 = sns.load_dataset("titanic")
sns.violinplot(df2["age"])
# Out:
# <Axes: ylabel='age'>
